# %%
freq=[round(x/len(freq0),3) for x in freq0]

prob={}
for i in range (0,len(chars)):
    prob[freq[i]]=chars[i]

for i in sorted (prob.keys()) : 
    print(f"{prob[i]} – {i} – {dict_coding[prob[i]]}")
# Out:
# a – 0.833 – 1100
# b – 1.5 – 1101
# c – 2.0 – 100
# d – 2.167 – 101
# e – 2.667 – 111
# f – 7.5 – 0

# %%
dct_new=countfrequency("GirlsFileText.txt")

# %%
keys=[]
values=[]
for i in dct_new:
    keys.append(i)
    values.append(dct_new[i])
encode=listNodes(Huffman(keys,values))
# Out:
# Node 0 L F sum of 0.0033783783783783786
# L is (0)
# F is (1)
#
# Node 1 x
#  sum of 0.0033783783783783786
# x is (0)
#
#  is (1)
#
# Node 2 Y # sum of 0.0033783783783783786
# Y is (0)
# # is (1)
#
# Node 3 % & sum of 0.0033783783783783786
# % is (0)
# & is (1)
#
# Node 4 * @ sum of 0.0033783783783783786
# * is (0)
# @ is (1)
#
# Node 5 " 5 sum of 0.0033783783783783786
# " is (0)
# 5 is (1)
#
# Node 6 7 9 sum of 0.0033783783783783786
# 7 is (0)
# 9 is (1)
#
# Node 7 2 6 sum of 0.0033783783783783786
# 2 is (0)
# 6 is (1)
#
# Node 8 N $ sum of 0.006756756756756757
# N is (0)
# $ is (1)
#
# Node 9 1 3 sum of 0.006756756756756757
# 1 is (0)
# 3 is (1)
#
# Node 10 0 LF sum of 0.006756756756756757
# 0 is (0)
# L is (10)
# F is (11)
#
# Node 11 x
#  Y# sum of 0.006756756756756757
# x is (00)
#
#  is (01)
# Y is (10)
# # is (11)
#
# Node 12 %& *@ sum of 0.006756756756756757
# % is (00)
# & is (01)
# * is (10)
# @ is (11)
#
# Node 13 "5 79 sum of 0.006756756756756757
# " is (00)
# 5 is (01)
# 7 is (10)
# 9 is (11)
#
# Node 14 26 “ sum of 0.008445945945945946
# 2 is (00)
# 6 is (01)
# “ is (1)
#
# Node 15 ” ? sum of 0.010135135135135136
# ” is (0)
# ? is (1)
#
# Node 16 v ^ sum of 0.010135135135135136
# v is (0)
# ^ is (1)
#
# Node 17 p W sum of 0.013513513513513514
# p is (0)
# W is (1)
#
# Node 18 b N$ sum of 0.013513513513513514
# b is (0)
# N is (10)
# $ is (11)
#
# Node 19 13 0LF sum of 0.013513513513513514
# 1 is (00)
# 3 is (01)
# 0 is (10)
# L is (110)
# F is (111)
#
# Node 20 x
# Y# %&*@ sum of 0.013513513513513514
# x is (000)
#
#  is (001)
# Y is (010)
# # is (011)
# % is (100)
# & is (101)
# * is (110)
# @ is (111)
#
# Node 21 "579 26“ sum of 0.015202702702702704
# " is (000)
# 5 is (001)
# 7 is (010)
# 9 is (011)
# 2 is (100)
# 6 is (101)
# “ is (11)
#
# Node 22 , . sum of 0.02027027027027027
# , is (0)
# . is (1)
#
# Node 23 k ”? sum of 0.02027027027027027
# k is (0)
# ” is (10)
# ? is (11)
#
# Node 24 v^ g sum of 0.02364864864864865
# v is (00)
# ^ is (01)
# g is (1)
#
# Node 25 pW bN$ sum of 0.02702702702702703
# p is (00)
# W is (01)
# b is (10)
# N is (110)
# $ is (111)
#
# Node 26 130LF x
# Y#%&*@ sum of 0.02702702702702703
# 1 is (000)
# 3 is (001)
# 0 is (010)
# L is (0110)
# F is (0111)
# x is (1000)
#
#  is (1001)
# Y is (1010)
# # is (1011)
# % is (1100)
# & is (1101)
# * is (1110)
# @ is (1111)
#
# Node 27 u w sum of 0.030405405405405407
# u is (0)
# w is (1)
#
# Node 28 "57926“ y sum of 0.033783783783783786
# " is (0000)
# 5 is (0001)
# 7 is (0010)
# 9 is (0011)
# 2 is (0100)
# 6 is (0101)
# “ is (011)
# y is (1)
#
# Node 29 ,. k”? sum of 0.04054054054054054
# , is (00)
# . is (01)
# k is (10)
# ” is (110)
# ? is (111)
#
# Node 30 c m sum of 0.045608108108108114
# c is (0)
# m is (1)
#
# Node 31 v^g f sum of 0.05067567567567568
# v is (000)
# ^ is (001)
# g is (01)
# f is (1)
#
# Node 32 l d sum of 0.05405405405405406
# l is (0)
# d is (1)
#
# Node 33 pWbN$ 130LFx
# Y#%&*@ sum of 0.05405405405405406
# p is (000)
# W is (001)
# b is (010)
# N is (0110)
# $ is (0111)
# 1 is (1000)
# 3 is (1001)
# 0 is (1010)
# L is (10110)
# F is (10111)
# x is (11000)
#
#  is (11001)
# Y is (11010)
# # is (11011)
# % is (11100)
# & is (11101)
# * is (11110)
# @ is (11111)
#
# Node 34 uw "57926“y sum of 0.0641891891891892
# u is (00)
# w is (01)
# " is (10000)
# 5 is (10001)
# 7 is (10010)
# 9 is (10011)
# 2 is (10100)
# 6 is (10101)
# “ is (1011)
# y is (11)
#
# Node 35 h r sum of 0.07263513513513514
# h is (0)
# r is (1)
#
# Node 36 ,.k”? cm sum of 0.08614864864864866
# , is (000)
# . is (001)
# k is (010)
# ” is (0110)
# ? is (0111)
# c is (10)
# m is (11)
#
# Node 37 s v^gf sum of 0.09797297297297297
# s is (0)
# v is (1000)
# ^ is (1001)
# g is (101)
# f is (11)
#
# Node 38 o n sum of 0.10641891891891891
# o is (0)
# n is (1)
#
# Node 39 ld pWbN$130LFx
# Y#%&*@ sum of 0.10810810810810811
# l is (00)
# d is (01)
# p is (1000)
# W is (1001)
# b is (1010)
# N is (10110)
# $ is (10111)
# 1 is (11000)
# 3 is (11001)
# 0 is (11010)
# L is (110110)
# F is (110111)
# x is (111000)
#
#  is (111001)
# Y is (111010)
# # is (111011)
# % is (111100)
# & is (111101)
# * is (111110)
# @ is (111111)
#
# Node 40 i uw"57926“y sum of 0.1283783783783784
# i is (0)
# u is (100)
# w is (101)
# " is (110000)
# 5 is (110001)
# 7 is (110010)
# 9 is (110011)
# 2 is (110100)
# 6 is (110101)
# “ is (11011)
# y is (111)
#
# Node 41 a hr sum of 0.14358108108108109
# a is (0)
# h is (10)
# r is (11)
#
# Node 42 t e sum of 0.1570945945945946
# t is (0)
# e is (1)
#
# Node 43 ,.k”?cm sv^gf sum of 0.18412162162162163
# , is (0000)
# . is (0001)
# k is (0010)
# ” is (00110)
# ? is (00111)
# c is (010)
# m is (011)
# s is (10)
# v is (11000)
# ^ is (11001)
# g is (1101)
# f is (111)
#
# Node 44 on ldpWbN$130LFx
# Y#%&*@ sum of 0.21452702702702703
# o is (00)
# n is (01)
# l is (100)
# d is (101)
# p is (11000)
# W is (11001)
# b is (11010)
# N is (110110)
# $ is (110111)
# 1 is (111000)
# 3 is (111001)
# 0 is (111010)
# L is (1110110)
# F is (1110111)
# x is (1111000)
#
#  is (1111001)
# Y is (1111010)
# # is (1111011)
# % is (1111100)
# & is (1111101)
# * is (1111110)
# @ is (1111111)
#
# Node 45 iuw"57926“y ahr sum of 0.2719594594594595
# i is (00)
# u is (0100)
# w is (0101)
# " is (0110000)
# 5 is (0110001)
# 7 is (0110010)
# 9 is (0110011)
# 2 is (0110100)
# 6 is (0110101)
# “ is (011011)
# y is (0111)
# a is (10)
# h is (110)
# r is (111)
#
# Node 46 te   sum of 0.3293918918918919
# t is (00)
# e is (01)
#   is (1)
#
# Node 47 ,.k”?cmsv^gf onldpWbN$130LFx
# Y#%&*@ sum of 0.3986486486486487
# , is (00000)
# . is (00001)
# k is (00010)
# ” is (000110)
# ? is (000111)
# c is (0010)
# m is (0011)
# s is (010)
# v is (011000)
# ^ is (011001)
# g is (01101)
# f is (0111)
# o is (100)
# n is (101)
# l is (1100)
# d is (1101)
# p is (111000)
# W is (111001)
# b is (111010)
# N is (1110110)
# $ is (1110111)
# 1 is (1111000)
# 3 is (1111001)
# 0 is (1111010)
# L is (11110110)
# F is (11110111)
# x is (11111000)
#
#  is (11111001)
# Y is (11111010)
# # is (11111011)
# % is (11111100)
# & is (11111101)
# * is (11111110)
# @ is (11111111)
#
# Node 48 iuw"57926“yahr te  sum of 0.6013513513513513
# i is (000)
# u is (00100)
# w is (00101)
# " is (00110000)
# 5 is (00110001)
# 7 is (00110010)
# 9 is (00110011)
# 2 is (00110100)
# 6 is (00110101)
# “ is (0011011)
# y is (00111)
# a is (010)
# h is (0110)
# r is (0111)
# t is (100)
# e is (101)
#   is (11)
#
# Node 49 ,.k”?cmsv^gfonldpWbN$130LFx
# Y#%&*@ iuw"57926“yahrte  sum of 1.0
# , is (000000)
# . is (000001)
# k is (000010)
# ” is (0000110)
# ? is (0000111)
# c is (00010)
# m is (00011)
# s is (0010)
# v is (0011000)
# ^ is (0011001)
# g is (001101)
# f is (00111)
# o is (0100)
# n is (0101)
# l is (01100)
# d is (01101)
# p is (0111000)
# W is (0111001)
# b is (0111010)
# N is (01110110)
# $ is (01110111)
# 1 is (01111000)
# 3 is (01111001)
# 0 is (01111010)
# L is (011110110)
# F is (011110111)
# x is (011111000)
#
#  is (011111001)
# Y is (011111010)
# # is (011111011)
# % is (011111100)
# & is (011111101)
# * is (011111110)
# @ is (011111111)
# i is (1000)
# u is (100100)
# w is (100101)
# " is (100110000)
# 5 is (100110001)
# 7 is (100110010)
# 9 is (100110011)
# 2 is (100110100)
# 6 is (100110101)
# “ is (10011011)
# y is (100111)
# a is (1010)
# h is (10110)
# r is (10111)
# t is (1100)
# e is (1101)
#   is (111)
